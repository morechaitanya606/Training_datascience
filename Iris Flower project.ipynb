# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('iris .csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# #### Print the names of all iris flowers with petal length greater than 5.

# %%
x=df[df['petal_length']>5]
x['species']  #printing all values of iris flower
# Out:
# 83     Iris-versicolor
# 100     Iris-virginica
# 101     Iris-virginica
# 102     Iris-virginica
# 103     Iris-virginica
# 104     Iris-virginica
# 105     Iris-virginica
# 107     Iris-virginica
# 108     Iris-virginica
# 109     Iris-virginica
# 110     Iris-virginica
# 111     Iris-virginica
# 112     Iris-virginica
# 114     Iris-virginica
# 115     Iris-virginica
# 116     Iris-virginica
# 117     Iris-virginica
# 118     Iris-virginica
# 120     Iris-virginica
# 122     Iris-virginica
# 124     Iris-virginica
# 125     Iris-virginica
# 128     Iris-virginica
# 129     Iris-virginica
# 130     Iris-virginica
# 131     Iris-virginica
# 132     Iris-virginica
# 133     Iris-virginica
# 134     Iris-virginica
# 135     Iris-virginica
# 136     Iris-virginica
# 137     Iris-virginica
# 139     Iris-virginica
# 140     Iris-virginica
# 141     Iris-virginica
# 142     Iris-virginica
# 143     Iris-virginica
# 144     Iris-virginica
# 145     Iris-virginica
# 147     Iris-virginica
# 148     Iris-virginica
# 149     Iris-virginica
# Name: species, dtype: object

# %% [markdown]
# #### Sort and print the names of iris flowers with sepal width less than 3.

# %%
j=df[df['sepal_width']<3]
j.sort_values(by='species')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 41            4.5          2.3           1.3          0.3      Iris-setosa
# 79            5.7          2.6           3.5          1.0  Iris-versicolor
# 80            5.5          2.4           3.8          1.1  Iris-versicolor
# 81            5.5          2.4           3.7          1.0  Iris-versicolor
# 82            5.8          2.7           3.9          1.2  Iris-versicolor
# 83            6.0          2.7           5.1          1.6  Iris-versicolor
# 87            6.3          2.3           4.4          1.3  Iris-versicolor
# 89            5.5          2.5           4.0          1.3  Iris-versicolor
# 92            5.8          2.6           4.0          1.2  Iris-versicolor
# 93            5.0          2.3           3.3          1.0  Iris-versicolor
# 94            5.6          2.7           4.2          1.3  Iris-versicolor
# 96            5.7          2.9           4.2          1.3  Iris-versicolor
# 97            6.2          2.9           4.3          1.3  Iris-versicolor
# 98            5.1          2.5           3.0          1.1  Iris-versicolor
# 99            5.7          2.8           4.1          1.3  Iris-versicolor
# 78            6.0          2.9           4.5          1.5  Iris-versicolor
# 76            6.8          2.8           4.8          1.4  Iris-versicolor
# 90            5.5          2.6           4.4          1.2  Iris-versicolor
# 73            6.1          2.8           4.7          1.2  Iris-versicolor
# 74            6.4          2.9           4.3          1.3  Iris-versicolor
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# 55            5.7          2.8           4.5          1.3  Iris-versicolor
# 57            4.9          2.4           3.3          1.0  Iris-versicolor
# 59            5.2          2.7           3.9          1.4  Iris-versicolor
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
# 58            6.6          2.9           4.6          1.3  Iris-versicolor
# 63            6.1          2.9           4.7          1.4  Iris-versicolor
# 64            5.6          2.9           3.6          1.3  Iris-versicolor
# 67            5.8          2.7           4.1          1.0  Iris-versicolor
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# 69            5.6          2.5           3.9          1.1  Iris-versicolor
# 71            6.1          2.8           4.0          1.3  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 72            6.3          2.5           4.9          1.5  Iris-versicolor
# 134           6.1          2.6           5.6          1.4   Iris-virginica
# 123           6.3          2.7           4.9          1.8   Iris-virginica
# 126           6.2          2.8           4.8          1.8   Iris-virginica
# 128           6.4          2.8           5.6          2.1   Iris-virginica
# 133           6.3          2.8           5.1          1.5   Iris-virginica
# 132           6.4          2.8           5.6          2.2   Iris-virginica
# 122           7.7          2.8           6.7          2.0   Iris-virginica
# 130           7.4          2.8           6.1          1.9   Iris-virginica
# 121           5.6          2.8           4.9          2.0   Iris-virginica
# 103           6.3          2.9           5.6          1.8   Iris-virginica
# 118           7.7          2.6           6.9          2.3   Iris-virginica
# 114           5.8          2.8           5.1          2.4   Iris-virginica
# 113           5.7          2.5           5.0          2.0   Iris-virginica
# 111           6.4          2.7           5.3          1.9   Iris-virginica
# 108           6.7          2.5           5.8          1.8   Iris-virginica
# 107           7.3          2.9           6.3          1.8   Iris-virginica
# 106           4.9          2.5           4.5          1.7   Iris-virginica
# 101           5.8          2.7           5.1          1.9   Iris-virginica
# 142           5.8          2.7           5.1          1.9   Iris-virginica
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# 146           6.3          2.5           5.0          1.9   Iris-virginica

# %% [markdown]
# ####  How many samples are there for each species?

# %%
df['species'].describe()
# Out:
# count             150
# unique              3
# top       Iris-setosa
# freq               50
# Name: species, dtype: object

# %%
df['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# #### Print the sepal length and width of iris flowers (non-null values) with petal width less than 1.

# %%
m = df[(df['petal_width'] < 1) & (df['sepal_length'].notnull()) & (df['sepal_width'].notnull())]
m[['sepal_length','sepal_width']]
# Out:
#     sepal_length  sepal_width
# 0            5.1          3.5
# 1            4.9          3.0
# 2            4.7          3.2
# 3            4.6          3.1
# 4            5.0          3.6
# 5            5.4          3.9
# 6            4.6          3.4
# 7            5.0          3.4
# 8            4.4          2.9
# 9            4.9          3.1
# 10           5.4          3.7
# 11           4.8          3.4
# 12           4.8          3.0
# 13           4.3          3.0
# 14           5.8          4.0
# 15           5.7          4.4
# 16           5.4          3.9
# 17           5.1          3.5
# 18           5.7          3.8
# 19           5.1          3.8
# 20           5.4          3.4
# 21           5.1          3.7
# 22           4.6          3.6
# 23           5.1          3.3
# 24           4.8          3.4
# 25           5.0          3.0
# 26           5.0          3.4
# 27           5.2          3.5
# 28           5.2          3.4
# 29           4.7          3.2
# 30           4.8          3.1
# 31           5.4          3.4
# 32           5.2          4.1
# 33           5.5          4.2
# 34           4.9          3.1
# 35           5.0          3.2
# 36           5.5          3.5
# 37           4.9          3.1
# 38           4.4          3.0
# 39           5.1          3.4
# 40           5.0          3.5
# 41           4.5          2.3
# 42           4.4          3.2
# 43           5.0          3.5
# 44           5.1          3.8
# 45           4.8          3.0
# 46           5.1          3.8
# 47           4.6          3.2
# 48           5.3          3.7
# 49           5.0          3.3

# %% [markdown]
# #### How many iris flowers have petal length greater than 6 and sepal width less than 3?

# %%
x=df[(df['petal_length']>6) & (df['sepal_width']<3)]
k=len(x)
k
# Out:
# 4

# %% [markdown]
# #### How many samples are there for each species in total?

# %%
df['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# #### Print the names of iris flowers with sepal length greater than 7 and petal width less than 0.3.

# %%
x=df[(df['sepal_length']>7) & (df['petal_width']<0.3)]
x['species']
# Out:
# Series([], Name: species, dtype: object)

# %% [markdown]
# #### Print the names of iris flowers with the highest and lowest petal lengths.

# %%
x = df.sort_values(by='petal_length')
m =x.iloc[0]['species']
n =x.iloc[-1]['species']
print("Flower with the lowest petal length:",m)
print("Flower with the highest petal length:", n)
# Out:
# Flower with the lowest petal length: Iris-setosa
# Flower with the highest petal length: Iris-virginica

# %% [markdown]
# #### Find information about the iris flowers with the widest sepals.

# %%
x= df['sepal_width'].max()
m= df[df['sepal_width'] == x]

# Print information about the iris flowers with the widest sepals
print("Information about iris flowers with the widest sepals:")
print(m)
# Out:
# Information about iris flowers with the widest sepals:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 15           5.7          4.4           1.5          0.4  Iris-setosa

# %% [markdown]
# #### Plot the distribution of petal lengths for each species.

# %%
import matplotlib.pyplot as plt

# %%
grouped_data = df.groupby('species')['petal_length'].apply(list)

# Plot the distribution of petal lengths for each species
plt.figure(figsize=(8, 6))
plt.hist(grouped_data, bins=10, label=grouped_data.index)
plt.xlabel('Petal Length')
plt.ylabel('Frequency')
plt.title('Distribution of Petal Lengths for Each Species')
plt.legend(title='Species')
plt.grid(True)
plt.show()
